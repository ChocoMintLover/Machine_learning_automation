# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
from keras.layers import LSTM, Dropout, Dense
from keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import TimeSeriesSplit
from sklearn.preprocessing import MinMaxScaler
import glob
import os

dataset_path = './datasets/Classical/'

# %% [markdown]
# npz파일로 된 dataset을 pd로 바꿔서 전처리하기 위해 만듬.
# 현재 코드에서는 자동화되었기 때문에 큰 쓸모는 없는듯

# %%
# npz data to pd.
def npz_to_csv(file_path):
    file = np.load(file_path, allow_pickle=True)
    X_df = pd.DataFrame(file['X'])
    y_df = pd.DataFrame(file['y'])
    return X_df, y_df

# %% [markdown]
# Time series 데이터에대하여 Pandas dataframe을 입력으로 받으면 lstm모델로 학습 후, 검증 loss값들과 accuracy값들을 return해주는 함수

# %%
def train_and_evaluate_lstm(X, y, n_splits=5, epochs=30, batch_size=32):
    # 데이터 정규화
    scaler = MinMaxScaler()
    X_scaled = scaler.fit_transform(X)
    
    tscv = TimeSeriesSplit(n_splits=n_splits)
    val_losses = []
    val_accs = []
    
    fold = 1
    for train_idx, test_idx in tscv.split(X_scaled):
        X_train, X_test = X_scaled[train_idx], X_scaled[test_idx]
        y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]
        
        # Input shape 맞추기 위함
        X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
        X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))
        
        model = Sequential()
        model.add(LSTM(units=50, input_shape=(X_train.shape[1], 1), return_sequences=True))
        model.add(Dropout(0.2))
        model.add(LSTM(units=50, return_sequences=False))
        model.add(Dropout(0.2))
        model.add(Dense(units=1, activation='sigmoid'))

        model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])
        
        history = model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(X_test, y_test), verbose=1)
        
        # 가장 좋은 검증 성능을 기록
        best_val_loss = min(history.history['val_loss'])
        best_val_acc = max(history.history['val_accuracy'])
        val_losses.append(best_val_loss)
        val_accs.append(best_val_acc)
        
        print(f"Fold {fold}, Best Validation Loss: {best_val_loss}, Best Validation Accuracy: {best_val_acc}")
        
        fold += 1

    mean_val_loss = np.mean(val_losses)
    mean_val_acc = np.mean(val_accs)
    
    print(f"Mean Best Validation Loss: {mean_val_loss}")
    print(f"Mean Best Validation Accuracy: {mean_val_acc}")
    
    return val_losses, val_accs

# %% [markdown]
# val losses와 val acc를 한 번에 plotting하는 함수

# %%
def plot_validation_metrics(val_losses, val_accs):
    num_folds = len(val_losses)
    
    folds = range(1, num_folds + 1)
    
    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(8, 6), sharex=True)
    
    ax1.plot(folds, val_losses, marker='o', linestyle='-', color='b')
    ax1.set_ylabel('Validation Loss')
    ax1.set_title('Validation Loss and Accuracy')
    ax1.grid(True)
    
    ax2.plot(folds, val_accs, marker='o', linestyle='-', color='g')
    ax2.set_xlabel('Fold')
    ax2.set_ylabel('Validation Accuracy')
    ax2.grid(True)
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# Anomaly data 비율을 나타내는 함수.
# 혹시 너무 accuracy가 정확하게 나오는 경우, 모든 데이터셋에 대하여 0이라고 판단했는데 알고보니 레이블이 0인 데이터의 개수가 엄청나게 많을 수 있음.
# 따라서 항상 의심할 것

# %%
def get_anomaly_rate(y):
    return y.value_counts()[1] / (y.value_counts()[0] + y.value_counts()[1])

# %% [markdown]
# 모든 val_losses와 val_accs를 데이터셋 인덱스에 따라 dictionary로 저장하기 위한 변수

# %%
val_dict = {}
def append_to_val_dict(index, val_loss, val_acc):
    val_dict[index] = (val_loss, val_acc)

# %% [markdown]
# 학습 완료된 경우 스프레드시트에 적어주세요!
# 한 데이터셋에 너무 시간을 많이 쓰실 필요는 없습니다. 학습할 내용도 많고 다른 모델도 많이 테스트해봐야 해요.
# 그리고 학습은 각 데이터셋에 대해 시간이 어느정도 소요되기 때문에 학습 과정에서는 다른 공부 하시는걸 추천드립니다.

# %%
# file_path = '/path/to/Classical' 각자가 저장한 폴더로 연결해주세요
file_path = './datasets/Classical/*.npz'
file_list = glob.glob(file_path)

# %%
file_list
# Out:
# ['./datasets/Classical\\1_wafer.npz',
#  './datasets/Classical\\2_pdm_anreal.npz',
#  './datasets/Classical\\3_tempSF.npz']

# %% [markdown]
# 폴더안에 자동으로 학습하고 기록하고싶은 데이터만 넣어두고, 이 밑에 코드 돌려두세요.

# %%
anomaly_rates = {}
file_idx = 1
for file in file_list:
    file = np.load(file_path, allow_pickle=True)
    X = file(['X'])
    y = file(['y'])
    
    anomaly_rates[file_idx] = get_anomaly_rate(y)
    val_losses, val_accs = train_and_evaluate_lstm(X, y)
    append_to_val_dict(file_idx, val_losses, val_accs)
    file_idx += 1
# Out:
# Epoch 1/30
# 10/10 [==============================] - 4s 216ms/step - loss: 0.6517 - accuracy: 0.8624 - val_loss: 0.5017 - val_accuracy: 0.9283
# Epoch 2/30
# 10/10 [==============================] - 2s 165ms/step - loss: 0.4064 - accuracy: 0.9060 - val_loss: 0.2735 - val_accuracy: 0.9283
# Epoch 3/30
# 10/10 [==============================] - 2s 164ms/step - loss: 0.3252 - accuracy: 0.9060 - val_loss: 0.2746 - val_accuracy: 0.9283
# Epoch 4/30
# 10/10 [==============================] - 2s 164ms/step - loss: 0.3171 - accuracy: 0.9060 - val_loss: 0.2623 - val_accuracy: 0.9283
# Epoch 5/30
# 10/10 [==============================] - 2s 162ms/step - loss: 0.3211 - accuracy: 0.9060 - val_loss: 0.2606 - val_accuracy: 0.9283
# Epoch 6/30
# 10/10 [==============================] - 2s 163ms/step - loss: 0.3120 - accuracy: 0.9060 - val_loss: 0.2614 - val_accuracy: 0.9283
# Epoch 7/30
# 10/10 [==============================] - 2s 160ms/step - loss: 0.3232 - accuracy: 0.9060 - val_loss: 0.2612 - val_accuracy: 0.9283
# Epoch 8/30
# 10/10 [==============================] - 2s 162ms/step - loss: 0.3158 - accuracy: 0.9060 - val_loss: 0.2617 - val_accuracy: 0.9283
# Epoch 9/30
# 10/10 [==============================] - 2s 169ms/step - loss: 0.3150 - accuracy: 0.9060 - val_loss: 0.2614 - val_accuracy: 0.9283
# Epoch 10/30
# 10/10 [==============================] - 2s 167ms/step - loss: 0.3123 - accuracy: 0.9060 - val_loss: 0.2614 - val_accuracy: 0.9283
# Epoch 11/30
# 10/10 [==============================] - 2s 174ms/step - loss: 0.3115 - accuracy: 0.9060 - val_loss: 0.2580 - val_accuracy: 0.9283
# Epoch 12/30
# 10/10 [==============================] - 2s 162ms/step - loss: 0.3103 - accuracy: 0.9060 - val_loss: 0.2579 - val_accuracy: 0.9283
# Epoch 13/30
# 10/10 [==============================] - 2s 163ms/step - loss: 0.3130 - accuracy: 0.9060 - val_loss: 0.2632 - val_accuracy: 0.9283
# Epoch 14/30
# 10/10 [==============================] - 2s 162ms/step - loss: 0.3149 - accuracy: 0.9060 - val_loss: 0.2638 - val_accuracy: 0.9283
# Epoch 15/30
# 10/10 [==============================] - 2s 161ms/step - loss: 0.3146 - accuracy: 0.9060 - val_loss: 0.2592 - val_accuracy: 0.9283
# Epoch 16/30
# 10/10 [==============================] - 2s 158ms/step - loss: 0.3128 - accuracy: 0.9060 - val_loss: 0.2589 - val_accuracy: 0.9283
# Epoch 17/30
# 10/10 [==============================] - 2s 159ms/step - loss: 0.3135 - accuracy: 0.9060 - val_loss: 0.2634 - val_accuracy: 0.9283
# Epoch 18/30
# 10/10 [==============================] - 2s 157ms/step - loss: 0.3130 - accuracy: 0.9060 - val_loss: 0.2614 - val_accuracy: 0.9283
# Epoch 19/30
# 10/10 [==============================] - 2s 158ms/step - loss: 0.3147 - accuracy: 0.9060 - val_loss: 0.2588 - val_accuracy: 0.9283
# Epoch 20/30
# 10/10 [==============================] - 2s 158ms/step - loss: 0.3151 - accuracy: 0.9060 - val_loss: 0.2681 - val_accuracy: 0.9283
# Epoch 21/30
# 10/10 [==============================] - 2s 159ms/step - loss: 0.3112 - accuracy: 0.9060 - val_loss: 0.2587 - val_accuracy: 0.9283
# Epoch 22/30
# 10/10 [==============================] - 2s 158ms/step - loss: 0.3137 - accuracy: 0.9060 - val_loss: 0.2564 - val_accuracy: 0.9283
# Epoch 23/30
# 10/10 [==============================] - 2s 157ms/step - loss: 0.3147 - accuracy: 0.9060 - val_loss: 0.2658 - val_accuracy: 0.9283
# Epoch 24/30
# 10/10 [==============================] - 2s 157ms/step - loss: 0.3124 - accuracy: 0.9060 - val_loss: 0.2580 - val_accuracy: 0.9283
# Epoch 25/30
# 10/10 [==============================] - 2s 161ms/step - loss: 0.3108 - accuracy: 0.9060 - val_loss: 0.2642 - val_accuracy: 0.9283
# Epoch 26/30
# 10/10 [==============================] - 2s 165ms/step - loss: 0.3196 - accuracy: 0.9060 - val_loss: 0.2551 - val_accuracy: 0.9283
# Epoch 27/30
# 10/10 [==============================] - 2s 164ms/step - loss: 0.3181 - accuracy: 0.9060 - val_loss: 0.2564 - val_accuracy: 0.9283
# Epoch 28/30
# 10/10 [==============================] - 2s 161ms/step - loss: 0.3110 - accuracy: 0.9060 - val_loss: 0.2583 - val_accuracy: 0.9283
# Epoch 29/30
# 10/10 [==============================] - 2s 161ms/step - loss: 0.2982 - accuracy: 0.9060 - val_loss: 0.2695 - val_accuracy: 0.9283
# Epoch 30/30
# 10/10 [==============================] - 2s 162ms/step - loss: 0.3126 - accuracy: 0.9027 - val_loss: 0.2642 - val_accuracy: 0.9283
# Fold 1, Best Validation Loss: 0.25505590438842773, Best Validation Accuracy: 0.9283276200294495
# Epoch 1/30
# 19/19 [==============================] - 5s 155ms/step - loss: 0.5059 - accuracy: 0.9086 - val_loss: 0.4299 - val_accuracy: 0.9044
# Epoch 2/30
# 19/19 [==============================] - 2s 131ms/step - loss: 0.3178 - accuracy: 0.9171 - val_loss: 0.3163 - val_accuracy: 0.9044
# Epoch 3/30
# 19/19 [==============================] - 3s 134ms/step - loss: 0.2968 - accuracy: 0.9171 - val_loss: 0.3162 - val_accuracy: 0.9044
# Epoch 4/30
# 19/19 [==============================] - 3s 135ms/step - loss: 0.2924 - accuracy: 0.9171 - val_loss: 0.3169 - val_accuracy: 0.9044
# Epoch 5/30
# 19/19 [==============================] - 3s 137ms/step - loss: 0.2880 - accuracy: 0.9171 - val_loss: 0.3171 - val_accuracy: 0.9044
# Epoch 6/30
# 19/19 [==============================] - 3s 138ms/step - loss: 0.2866 - accuracy: 0.9171 - val_loss: 0.3164 - val_accuracy: 0.9044
# Epoch 7/30
# 19/19 [==============================] - 3s 136ms/step - loss: 0.2901 - accuracy: 0.9171 - val_loss: 0.3159 - val_accuracy: 0.9044
# Epoch 8/30
# 19/19 [==============================] - 3s 137ms/step - loss: 0.2877 - accuracy: 0.9171 - val_loss: 0.3155 - val_accuracy: 0.9044
# Epoch 9/30
# 19/19 [==============================] - 2s 133ms/step - loss: 0.2882 - accuracy: 0.9171 - val_loss: 0.3162 - val_accuracy: 0.9044
# Epoch 10/30
# 19/19 [==============================] - 3s 134ms/step - loss: 0.2891 - accuracy: 0.9171 - val_loss: 0.3180 - val_accuracy: 0.9044
# Epoch 11/30
# 19/19 [==============================] - 3s 134ms/step - loss: 0.2903 - accuracy: 0.9171 - val_loss: 0.3155 - val_accuracy: 0.9044
# Epoch 12/30
# 19/19 [==============================] - 3s 135ms/step - loss: 0.2864 - accuracy: 0.9171 - val_loss: 0.3180 - val_accuracy: 0.9044
# Epoch 13/30
# 19/19 [==============================] - 3s 133ms/step - loss: 0.2872 - accuracy: 0.9171 - val_loss: 0.3152 - val_accuracy: 0.9044
# Epoch 14/30
# 19/19 [==============================] - 2s 129ms/step - loss: 0.2920 - accuracy: 0.9171 - val_loss: 0.3176 - val_accuracy: 0.9044
# Epoch 15/30
# 19/19 [==============================] - 2s 124ms/step - loss: 0.2942 - accuracy: 0.9171 - val_loss: 0.3151 - val_accuracy: 0.9044
# Epoch 16/30
# 19/19 [==============================] - 2s 126ms/step - loss: 0.2879 - accuracy: 0.9171 - val_loss: 0.3171 - val_accuracy: 0.9044
# Epoch 17/30
# 19/19 [==============================] - 2s 125ms/step - loss: 0.2887 - accuracy: 0.9171 - val_loss: 0.3170 - val_accuracy: 0.9044
# Epoch 18/30
# 19/19 [==============================] - 2s 122ms/step - loss: 0.2900 - accuracy: 0.9171 - val_loss: 0.3150 - val_accuracy: 0.9044
# Epoch 19/30
# 19/19 [==============================] - 2s 121ms/step - loss: 0.2867 - accuracy: 0.9171 - val_loss: 0.3168 - val_accuracy: 0.9044
# Epoch 20/30
# 19/19 [==============================] - 2s 121ms/step - loss: 0.2856 - accuracy: 0.9171 - val_loss: 0.3147 - val_accuracy: 0.9044
# Epoch 21/30
# 19/19 [==============================] - 2s 121ms/step - loss: 0.2828 - accuracy: 0.9171 - val_loss: 0.3157 - val_accuracy: 0.9044
# Epoch 22/30
# 19/19 [==============================] - 2s 121ms/step - loss: 0.2900 - accuracy: 0.9171 - val_loss: 0.3163 - val_accuracy: 0.9044
# Epoch 23/30
# 19/19 [==============================] - 2s 121ms/step - loss: 0.2855 - accuracy: 0.9171 - val_loss: 0.3163 - val_accuracy: 0.9044
# Epoch 24/30
# 19/19 [==============================] - 2s 122ms/step - loss: 0.2902 - accuracy: 0.9171 - val_loss: 0.3182 - val_accuracy: 0.9044
# Epoch 25/30
# 19/19 [==============================] - 2s 122ms/step - loss: 0.2897 - accuracy: 0.9171 - val_loss: 0.3148 - val_accuracy: 0.9044
# Epoch 26/30
# 19/19 [==============================] - 2s 121ms/step - loss: 0.2833 - accuracy: 0.9171 - val_loss: 0.3148 - val_accuracy: 0.9044
# Epoch 27/30
# 19/19 [==============================] - 2s 122ms/step - loss: 0.2819 - accuracy: 0.9171 - val_loss: 0.3170 - val_accuracy: 0.9044
# Epoch 28/30
# 19/19 [==============================] - 2s 121ms/step - loss: 0.2892 - accuracy: 0.9171 - val_loss: 0.3177 - val_accuracy: 0.9044
# Epoch 29/30
# 19/19 [==============================] - 2s 120ms/step - loss: 0.2905 - accuracy: 0.9171 - val_loss: 0.3145 - val_accuracy: 0.9044
# Epoch 30/30
# 19/19 [==============================] - 2s 122ms/step - loss: 0.2853 - accuracy: 0.9171 - val_loss: 0.3154 - val_accuracy: 0.9044
# Fold 2, Best Validation Loss: 0.31448590755462646, Best Validation Accuracy: 0.9044368863105774
# Epoch 1/30
# 28/28 [==============================] - 5s 127ms/step - loss: 0.4602 - accuracy: 0.9061 - val_loss: 0.2942 - val_accuracy: 0.9147
# Epoch 2/30
# 28/28 [==============================] - 3s 111ms/step - loss: 0.2981 - accuracy: 0.9129 - val_loss: 0.2931 - val_accuracy: 0.9147
# Epoch 3/30
# 28/28 [==============================] - 3s 111ms/step - loss: 0.3021 - accuracy: 0.9129 - val_loss: 0.2916 - val_accuracy: 0.9147
# Epoch 4/30
# 28/28 [==============================] - 3s 111ms/step - loss: 0.3040 - accuracy: 0.9129 - val_loss: 0.2916 - val_accuracy: 0.9147
# Epoch 5/30
# 28/28 [==============================] - 3s 112ms/step - loss: 0.2979 - accuracy: 0.9129 - val_loss: 0.2917 - val_accuracy: 0.9147
# Epoch 6/30
# 28/28 [==============================] - 3s 112ms/step - loss: 0.2982 - accuracy: 0.9129 - val_loss: 0.2914 - val_accuracy: 0.9147
# Epoch 7/30
# 28/28 [==============================] - 3s 111ms/step - loss: 0.3003 - accuracy: 0.9129 - val_loss: 0.2913 - val_accuracy: 0.9147
# Epoch 8/30
# 28/28 [==============================] - 3s 112ms/step - loss: 0.2980 - accuracy: 0.9129 - val_loss: 0.2912 - val_accuracy: 0.9147
# Epoch 9/30
# 28/28 [==============================] - 3s 113ms/step - loss: 0.3007 - accuracy: 0.9129 - val_loss: 0.2914 - val_accuracy: 0.9147
# Epoch 10/30
# 28/28 [==============================] - 3s 113ms/step - loss: 0.2981 - accuracy: 0.9129 - val_loss: 0.2911 - val_accuracy: 0.9147
# Epoch 11/30
# 28/28 [==============================] - 3s 112ms/step - loss: 0.2936 - accuracy: 0.9129 - val_loss: 0.2910 - val_accuracy: 0.9147
# Epoch 12/30
# 28/28 [==============================] - 3s 112ms/step - loss: 0.2989 - accuracy: 0.9129 - val_loss: 0.2912 - val_accuracy: 0.9147
# Epoch 13/30
# 28/28 [==============================] - 3s 113ms/step - loss: 0.3019 - accuracy: 0.9129 - val_loss: 0.2919 - val_accuracy: 0.9147
# Epoch 14/30
# 28/28 [==============================] - 3s 114ms/step - loss: 0.2985 - accuracy: 0.9129 - val_loss: 0.2903 - val_accuracy: 0.9147
# Epoch 15/30
# 28/28 [==============================] - 3s 114ms/step - loss: 0.2999 - accuracy: 0.9129 - val_loss: 0.2901 - val_accuracy: 0.9147
# Epoch 16/30
# 28/28 [==============================] - 3s 117ms/step - loss: 0.2974 - accuracy: 0.9129 - val_loss: 0.2898 - val_accuracy: 0.9147
# Epoch 17/30
# 28/28 [==============================] - 3s 116ms/step - loss: 0.2959 - accuracy: 0.9129 - val_loss: 0.2905 - val_accuracy: 0.9147
# Epoch 18/30
# 28/28 [==============================] - 3s 118ms/step - loss: 0.2979 - accuracy: 0.9129 - val_loss: 0.2892 - val_accuracy: 0.9147
# Epoch 19/30
# 28/28 [==============================] - 3s 119ms/step - loss: 0.2985 - accuracy: 0.9129 - val_loss: 0.2919 - val_accuracy: 0.9147
# Epoch 20/30
# 28/28 [==============================] - 3s 114ms/step - loss: 0.2968 - accuracy: 0.9129 - val_loss: 0.2901 - val_accuracy: 0.9147
# Epoch 21/30
# 28/28 [==============================] - 3s 111ms/step - loss: 0.2978 - accuracy: 0.9129 - val_loss: 0.2895 - val_accuracy: 0.9147
# Epoch 22/30
# 28/28 [==============================] - 3s 112ms/step - loss: 0.2949 - accuracy: 0.9129 - val_loss: 0.2887 - val_accuracy: 0.9147
# Epoch 23/30
# 28/28 [==============================] - 3s 111ms/step - loss: 0.2927 - accuracy: 0.9129 - val_loss: 0.2880 - val_accuracy: 0.9147
# Epoch 24/30
# 28/28 [==============================] - 3s 111ms/step - loss: 0.2957 - accuracy: 0.9129 - val_loss: 0.2889 - val_accuracy: 0.9147
# Epoch 25/30
# 28/28 [==============================] - 3s 112ms/step - loss: 0.2976 - accuracy: 0.9129 - val_loss: 0.2887 - val_accuracy: 0.9147
# Epoch 26/30
# 28/28 [==============================] - 3s 111ms/step - loss: 0.2958 - accuracy: 0.9129 - val_loss: 0.2898 - val_accuracy: 0.9147
# Epoch 27/30
# 28/28 [==============================] - 3s 110ms/step - loss: 0.2947 - accuracy: 0.9129 - val_loss: 0.2899 - val_accuracy: 0.9147
# Epoch 28/30
# 28/28 [==============================] - 3s 111ms/step - loss: 0.2965 - accuracy: 0.9129 - val_loss: 0.2897 - val_accuracy: 0.9147
# Epoch 29/30
# 28/28 [==============================] - 3s 110ms/step - loss: 0.2955 - accuracy: 0.9129 - val_loss: 0.2897 - val_accuracy: 0.9147
# Epoch 30/30
# 28/28 [==============================] - 3s 110ms/step - loss: 0.2967 - accuracy: 0.9129 - val_loss: 0.2895 - val_accuracy: 0.9147
# Fold 3, Best Validation Loss: 0.2880362868309021, Best Validation Accuracy: 0.914675772190094
# Epoch 1/30
# 37/37 [==============================] - 6s 117ms/step - loss: 0.4135 - accuracy: 0.9065 - val_loss: 0.2791 - val_accuracy: 0.9249
# Epoch 2/30
# 37/37 [==============================] - 4s 110ms/step - loss: 0.2982 - accuracy: 0.9133 - val_loss: 0.2665 - val_accuracy: 0.9249
# Epoch 3/30
# 37/37 [==============================] - 4s 112ms/step - loss: 0.2992 - accuracy: 0.9133 - val_loss: 0.2661 - val_accuracy: 0.9249
# Epoch 4/30
# 37/37 [==============================] - 4s 112ms/step - loss: 0.2976 - accuracy: 0.9133 - val_loss: 0.2683 - val_accuracy: 0.9249
# Epoch 5/30
# 37/37 [==============================] - 4s 114ms/step - loss: 0.2990 - accuracy: 0.9133 - val_loss: 0.2657 - val_accuracy: 0.9249
# Epoch 6/30
# 37/37 [==============================] - 4s 111ms/step - loss: 0.2964 - accuracy: 0.9133 - val_loss: 0.2688 - val_accuracy: 0.9249
# Epoch 7/30
# 37/37 [==============================] - 4s 110ms/step - loss: 0.2944 - accuracy: 0.9133 - val_loss: 0.2659 - val_accuracy: 0.9249
# Epoch 8/30
# 37/37 [==============================] - 4s 108ms/step - loss: 0.2961 - accuracy: 0.9133 - val_loss: 0.2646 - val_accuracy: 0.9249
# Epoch 9/30
# 37/37 [==============================] - 4s 111ms/step - loss: 0.2994 - accuracy: 0.9133 - val_loss: 0.2735 - val_accuracy: 0.9249
# Epoch 10/30
# 37/37 [==============================] - 4s 110ms/step - loss: 0.2972 - accuracy: 0.9133 - val_loss: 0.2661 - val_accuracy: 0.9249
# Epoch 11/30
# 37/37 [==============================] - 4s 110ms/step - loss: 0.2931 - accuracy: 0.9133 - val_loss: 0.2645 - val_accuracy: 0.9249
# Epoch 12/30
# 37/37 [==============================] - 4s 110ms/step - loss: 0.2971 - accuracy: 0.9133 - val_loss: 0.2633 - val_accuracy: 0.9249
# Epoch 13/30
# 37/37 [==============================] - 4s 109ms/step - loss: 0.2980 - accuracy: 0.9133 - val_loss: 0.2640 - val_accuracy: 0.9249
# Epoch 14/30
# 37/37 [==============================] - 4s 108ms/step - loss: 0.2945 - accuracy: 0.9125 - val_loss: 0.2622 - val_accuracy: 0.9249
# Epoch 15/30
# 37/37 [==============================] - 4s 108ms/step - loss: 0.2978 - accuracy: 0.9133 - val_loss: 0.2614 - val_accuracy: 0.9249
# Epoch 16/30
# 37/37 [==============================] - 4s 109ms/step - loss: 0.3023 - accuracy: 0.9116 - val_loss: 0.2664 - val_accuracy: 0.9249
# Epoch 17/30
# 37/37 [==============================] - 4s 108ms/step - loss: 0.2960 - accuracy: 0.9133 - val_loss: 0.2673 - val_accuracy: 0.9249
# Epoch 18/30
# 37/37 [==============================] - 4s 111ms/step - loss: 0.2964 - accuracy: 0.9133 - val_loss: 0.2635 - val_accuracy: 0.9249
# Epoch 19/30
# 37/37 [==============================] - 4s 108ms/step - loss: 0.2952 - accuracy: 0.9133 - val_loss: 0.2612 - val_accuracy: 0.9249
# Epoch 20/30
# 37/37 [==============================] - 4s 108ms/step - loss: 0.2925 - accuracy: 0.9125 - val_loss: 0.2685 - val_accuracy: 0.9283
# Epoch 21/30
# 37/37 [==============================] - 4s 109ms/step - loss: 0.2939 - accuracy: 0.9133 - val_loss: 0.2693 - val_accuracy: 0.9249
# Epoch 22/30
# 37/37 [==============================] - 4s 109ms/step - loss: 0.2937 - accuracy: 0.9133 - val_loss: 0.2650 - val_accuracy: 0.9249
# Epoch 23/30
# 37/37 [==============================] - 4s 107ms/step - loss: 0.2965 - accuracy: 0.9133 - val_loss: 0.2641 - val_accuracy: 0.9249
# Epoch 24/30
# 37/37 [==============================] - 4s 107ms/step - loss: 0.2923 - accuracy: 0.9133 - val_loss: 0.2660 - val_accuracy: 0.9249
# Epoch 25/30
# 37/37 [==============================] - 4s 107ms/step - loss: 0.2956 - accuracy: 0.9133 - val_loss: 0.2596 - val_accuracy: 0.9249
# Epoch 26/30
# 37/37 [==============================] - 4s 109ms/step - loss: 0.3153 - accuracy: 0.8955 - val_loss: 0.2651 - val_accuracy: 0.9249
# Epoch 27/30
# 37/37 [==============================] - 4s 109ms/step - loss: 0.2978 - accuracy: 0.9133 - val_loss: 0.2650 - val_accuracy: 0.9249
# Epoch 28/30
# 37/37 [==============================] - 4s 109ms/step - loss: 0.2958 - accuracy: 0.9133 - val_loss: 0.2674 - val_accuracy: 0.9249
# Epoch 29/30
# 37/37 [==============================] - 4s 109ms/step - loss: 0.2944 - accuracy: 0.9133 - val_loss: 0.2654 - val_accuracy: 0.9249
# Epoch 30/30
# 37/37 [==============================] - 4s 109ms/step - loss: 0.2948 - accuracy: 0.9133 - val_loss: 0.2666 - val_accuracy: 0.9249
# Fold 4, Best Validation Loss: 0.25959956645965576, Best Validation Accuracy: 0.9283276200294495
# Epoch 1/30
# 46/46 [==============================] - 7s 114ms/step - loss: 0.3951 - accuracy: 0.9102 - val_loss: 0.2449 - val_accuracy: 0.9352
# Epoch 2/30
# 46/46 [==============================] - 5s 103ms/step - loss: 0.2946 - accuracy: 0.9156 - val_loss: 0.2427 - val_accuracy: 0.9352
# Epoch 3/30
# 46/46 [==============================] - 5s 104ms/step - loss: 0.2965 - accuracy: 0.9156 - val_loss: 0.2398 - val_accuracy: 0.9352
# Epoch 4/30
# 46/46 [==============================] - 5s 103ms/step - loss: 0.2954 - accuracy: 0.9156 - val_loss: 0.2471 - val_accuracy: 0.9352
# Epoch 5/30
# 46/46 [==============================] - 5s 104ms/step - loss: 0.2938 - accuracy: 0.9156 - val_loss: 0.2401 - val_accuracy: 0.9352
# Epoch 6/30
# 46/46 [==============================] - 5s 106ms/step - loss: 0.2913 - accuracy: 0.9156 - val_loss: 0.2437 - val_accuracy: 0.9352
# Epoch 7/30
# 46/46 [==============================] - 5s 106ms/step - loss: 0.2934 - accuracy: 0.9156 - val_loss: 0.2442 - val_accuracy: 0.9352
# Epoch 8/30
# 46/46 [==============================] - 5s 107ms/step - loss: 0.2905 - accuracy: 0.9156 - val_loss: 0.2384 - val_accuracy: 0.9352
# Epoch 9/30
# 46/46 [==============================] - 5s 106ms/step - loss: 0.2905 - accuracy: 0.9156 - val_loss: 0.2376 - val_accuracy: 0.9352
# Epoch 10/30
# 46/46 [==============================] - 5s 107ms/step - loss: 0.2867 - accuracy: 0.9156 - val_loss: 0.2377 - val_accuracy: 0.9352
# Epoch 11/30
# 46/46 [==============================] - 5s 106ms/step - loss: 0.2942 - accuracy: 0.9156 - val_loss: 0.2371 - val_accuracy: 0.9352
# Epoch 12/30
# 46/46 [==============================] - 5s 107ms/step - loss: 0.2885 - accuracy: 0.9156 - val_loss: 0.2356 - val_accuracy: 0.9352
# Epoch 13/30
# 46/46 [==============================] - 5s 108ms/step - loss: 0.2893 - accuracy: 0.9163 - val_loss: 0.2367 - val_accuracy: 0.9352
# Epoch 14/30
# 46/46 [==============================] - 5s 107ms/step - loss: 0.2927 - accuracy: 0.9156 - val_loss: 0.2408 - val_accuracy: 0.9352
# Epoch 15/30
# 46/46 [==============================] - 5s 106ms/step - loss: 0.2934 - accuracy: 0.9156 - val_loss: 0.2353 - val_accuracy: 0.9352
# Epoch 16/30
# 46/46 [==============================] - 5s 106ms/step - loss: 0.2927 - accuracy: 0.9156 - val_loss: 0.2354 - val_accuracy: 0.9352
# Epoch 17/30
# 46/46 [==============================] - 5s 106ms/step - loss: 0.2934 - accuracy: 0.9156 - val_loss: 0.2390 - val_accuracy: 0.9352
# Epoch 18/30
# 46/46 [==============================] - 5s 106ms/step - loss: 0.2940 - accuracy: 0.9156 - val_loss: 0.2402 - val_accuracy: 0.9352
# Epoch 19/30
# 46/46 [==============================] - 5s 106ms/step - loss: 0.2909 - accuracy: 0.9156 - val_loss: 0.2365 - val_accuracy: 0.9352
# Epoch 20/30
# 46/46 [==============================] - 5s 106ms/step - loss: 0.2883 - accuracy: 0.9156 - val_loss: 0.2371 - val_accuracy: 0.9352
# Epoch 21/30
# 46/46 [==============================] - ETA: 0s - loss: 0.2928 - accuracy: 0.9156

# %%
# plot_validation_metrics(val_losses, val_accs)
# 기록된 dict를 토대로 각 데이터셋에 대해 for문을 돌리던 indexing을 통해(val_dict[idx]~~)
# 접근하든 해서 plotting하는 함수입니다. loss 값과 accuracy값을 검증 fold마다 출력해줘요.

# %%
# plotting 예시
# plot_validation_metrics(val_dict[1][0], val_dict[1][1])
